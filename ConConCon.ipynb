# %%
import os

# Wipe out system CUDA paths
os.environ["LD_LIBRARY_PATH"] = ""

# Optional: point to jaxlib's internal CUDA (if known)
# os.environ["XLA_FLAGS"] = "--xla_gpu_cuda_data_dir=/path/to/cuda"

# Force CPU (already working)
os.environ["JAX_PLATFORM_NAME"] = "cpu"

# %%
# !pip uninstall jax jaxlib -y
# Out:
# Found existing installation: jax 0.4.30
# Uninstalling jax-0.4.30:
#   Successfully uninstalled jax-0.4.30
# Found existing installation: jaxlib 0.4.30
# Uninstalling jaxlib-0.4.30:
#   Successfully uninstalled jaxlib-0.4.30

# %%
# !pip install --upgrade pip
# !pip install --upgrade "jax[cuda12_pip]" -f https://storage.googleapis.com/jax-releases/jax_cuda_releases.html
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pip in /home/a/a270285/.local/lib/python3.9/site-packages (25.1.1)
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: https://storage.googleapis.com/jax-releases/jax_cuda_releases.html
# Collecting jax[cuda12_pip]
#   Using cached jax-0.4.30-py3-none-any.whl.metadata (22 kB)
# Collecting jaxlib<=0.4.30,>=0.4.27 (from jax[cuda12_pip])
#   Using cached jaxlib-0.4.30-cp39-cp39-manylinux2014_x86_64.whl.metadata (1.0 kB)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /home/a/a270285/.local/lib/python3.9/site-packages (from jax[cuda12_pip]) (0.5.1)
# Requirement already satisfied: numpy>=1.22 in /home/a/a270285/.local/lib/python3.9/site-packages (from jax[cuda12_pip]) (2.0.2)
# Requirement already satisfied: opt-einsum in /home/a/a270285/.local/lib/python3.9/site-packages (from jax[cuda12_pip]) (3.4.0)
# Requirement already satisfied: scipy>=1.9 in /home/a/a270285/.local/lib/python3.9/site-packages (from jax[cuda12_pip]) (1.13.1)
# Requirement already satisfied: importlib-metadata>=4.6 in /sw/spack-levante/jupyterhub/jupyterhub/lib/python3.9/site-packages (from jax[cuda12_pip]) (5.0.0)
# Requirement already satisfied: jax-cuda12-plugin<=0.4.30,>=0.4.30 in /home/a/a270285/.local/lib/python3.9/site-packages (from jax-cuda12-plugin[with_cuda]<=0.4.30,>=0.4.30; extra == "cuda12-pip"->jax[cuda12_pip]) (0.4.30)
# Requirement already satisfied: jax-cuda12-pjrt==0.4.30 in /home/a/a270285/.local/lib/python3.9/site-packages (from jax-cuda12-plugin<=0.4.30,>=0.4.30->jax-cuda12-plugin[with_cuda]<=0.4.30,>=0.4.30; extra == "cuda12-pip"->jax[cuda12_pip]) (0.4.30)
# Requirement already satisfied: nvidia-cublas-cu12>=12.1.3.1 in /home/a/a270285/.local/lib/python3.9/site-packages (from jax-cuda12-plugin[with_cuda]<=0.4.30,>=0.4.30; extra == "cuda12-pip"->jax[cuda12_pip]) (12.9.1.4)
# Requirement already satisfied: nvidia-cuda-cupti-cu12>=12.1.105 in /home/a/a270285/.local/lib/python3.9/site-packages (from jax-cuda12-plugin[with_cuda]<=0.4.30,>=0.4.30; extra == "cuda12-pip"->jax[cuda12_pip]) (12.9.79)
# Requirement already satisfied: nvidia-cuda-nvcc-cu12>=12.1.105 in /home/a/a270285/.local/lib/python3.9/site-packages (from jax-cuda12-plugin[with_cuda]<=0.4.30,>=0.4.30; extra == "cuda12-pip"->jax[cuda12_pip]) (12.9.86)
# Requirement already satisfied: nvidia-cuda-runtime-cu12>=12.1.105 in /home/a/a270285/.local/lib/python3.9/site-packages (from jax-cuda12-plugin[with_cuda]<=0.4.30,>=0.4.30; extra == "cuda12-pip"->jax[cuda12_pip]) (12.9.79)
# Requirement already satisfied: nvidia-cudnn-cu12<10.0,>=9.0 in /home/a/a270285/.local/lib/python3.9/site-packages (from jax-cuda12-plugin[with_cuda]<=0.4.30,>=0.4.30; extra == "cuda12-pip"->jax[cuda12_pip]) (9.10.2.21)
# Requirement already satisfied: nvidia-cufft-cu12>=11.0.2.54 in /home/a/a270285/.local/lib/python3.9/site-packages (from jax-cuda12-plugin[with_cuda]<=0.4.30,>=0.4.30; extra == "cuda12-pip"->jax[cuda12_pip]) (11.4.1.4)
# Requirement already satisfied: nvidia-cusolver-cu12>=11.4.5.107 in /home/a/a270285/.local/lib/python3.9/site-packages (from jax-cuda12-plugin[with_cuda]<=0.4.30,>=0.4.30; extra == "cuda12-pip"->jax[cuda12_pip]) (11.7.5.82)
# Requirement already satisfied: nvidia-cusparse-cu12>=12.1.0.106 in /home/a/a270285/.local/lib/python3.9/site-packages (from jax-cuda12-plugin[with_cuda]<=0.4.30,>=0.4.30; extra == "cuda12-pip"->jax[cuda12_pip]) (12.5.10.65)
# Requirement already satisfied: nvidia-nccl-cu12>=2.18.1 in /home/a/a270285/.local/lib/python3.9/site-packages (from jax-cuda12-plugin[with_cuda]<=0.4.30,>=0.4.30; extra == "cuda12-pip"->jax[cuda12_pip]) (2.27.5)
# Requirement already satisfied: nvidia-nvjitlink-cu12>=12.1.105 in /home/a/a270285/.local/lib/python3.9/site-packages (from jax-cuda12-plugin[with_cuda]<=0.4.30,>=0.4.30; extra == "cuda12-pip"->jax[cuda12_pip]) (12.9.86)
# Requirement already satisfied: zipp>=0.5 in /sw/spack-levante/jupyterhub/jupyterhub/lib/python3.9/site-packages (from importlib-metadata>=4.6->jax[cuda12_pip]) (3.10.0)
# Using cached jax-0.4.30-py3-none-any.whl (2.0 MB)
# Using cached jaxlib-0.4.30-cp39-cp39-manylinux2014_x86_64.whl (79.6 MB)
# Installing collected packages: jaxlib, jax
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [jax]1/2 [jax]
# Successfully installed jax-0.4.30 jaxlib-0.4.30

# %%
import jax
print("JAX version:", jax.__version__)
print("JAX devices:", jax.devices())
# Out:
# JAX version: 0.6.2
# JAX devices: [CudaDevice(id=0)]

# %%
import sys
print(sys.version)
# Out:
# 3.10.16 | packaged by conda-forge | (main, Dec  5 2024, 14:16:10) [GCC 13.3.0]

# %%
# !pip install nbimporter --quiet

# %%
#import nbimporter

from .synthetic_data_generator import create_synthetic_matrix, create_synthetic_data
from GNP import GNP
from ResGCN import ResGCN, scale_A_by_spectral_radius
from GMRES import GMRES
from scipy.sparse import csc_matrix, identity
import torch
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import math
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 3
#       1 #import nbimporter
# ----> 3 from .synthetic_data_generator import create_synthetic_matrix, create_synthetic_data
#       4 from GNP import GNP
#       5 from ResGCN import ResGCN, scale_A_by_spectral_radius
#
# ImportError: attempted relative import with no known parent package

# %%
Lx = 1000 # Size of domain in km
dxm = 2 # Mesh resolution in km
n2d = np.arange(0, Lx + 1, dxm, dtype="float32").shape[0]**2 # Number of mesh nodes

ss, ii, jj, tri, xcoord, ycoord = create_synthetic_matrix(Lx, dxm, False)
tt = create_synthetic_data(Lx, dxm)
# Out:
# E0627 07:56:02.263596 3292448 cuda_dnn.cc:523] Loaded runtime CuDNN library: 9.5.1 but source was compiled with: 9.8.0.  CuDNN library needs to have matching major version and equal or higher minor version. If using a binary install, upgrade your CuDNN library.  If building from sources, make sure the library loaded at runtime is compatible with the version specified during compile configuration.
# E0627 07:56:02.349500 3292448 cuda_dnn.cc:523] Loaded runtime CuDNN library: 9.5.1 but source was compiled with: 9.8.0.  CuDNN library needs to have matching major version and equal or higher minor version. If using a binary install, upgrade your CuDNN library.  If building from sources, make sure the library loaded at runtime is compatible with the version specified during compile configuration.
# ---------------------------------------------------------------------------
# XlaRuntimeError                           Traceback (most recent call last)
# Cell In[5], line 5
#       2 dxm = 2 # Mesh resolution in km
#       3 n2d = np.arange(0, Lx + 1, dxm, dtype="float32").shape[0]**2 # Number of mesh nodes
# ----> 5 ss, ii, jj, tri, xcoord, ycoord = create_synthetic_matrix(Lx, dxm, False)
#       6 tt = create_synthetic_data(Lx, dxm)
#
# File ~/PreCon/synthetic_data_creator.ipynb:348, in create_synthetic_matrix(Lx, dxm, cartesian)
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": 6,
#       6    "id": "37c95023-22d0-4e7f-a883-a10cbb50d805",
#       7    "metadata": {},
#       8    "outputs": [
#       9     {
#      10      "name": "stdout",
#      11      "output_type": "stream",
#      12      "text": [
#      13       "Found existing installation: jax 0.4.30\n",
#      14       "Uninstalling jax-0.4.30:\n",
#      15       "  Successfully uninstalled jax-0.4.30\n",
#      16       "Found existing installation: jaxlib 0.4.30\n",
#      17       "Uninstalling jaxlib-0.4.30:\n",
#      18       "  Successfully uninstalled jaxlib-0.4.30\n"
#      19      ]
#      20     }
#      21    ],
#      22    "source": [
#      23     "!pip uninstall jax jaxlib -y\n"
#      24    ]
#      25   },
#      26   {
#      27    "cell_type": "code",
#      28    "execution_count": 7,
#      29    "id": "50344bcb-bf30-4573-959e-e2f574401fdd",
#      30    "metadata": {},
#      31    "outputs": [
#      32     {
#      33      "name": "stdout",
#      34      "output_type": "stream",
#      35      "text": [
#      36       "Defaulting to user installation because normal site-packages is not writeable\n",
#      37       "Requirement already satisfied: pip in /home/a/a270285/.local/lib/python3.9/site-packages (25.1.1)\n",
#      38       "Defaulting to user installation because normal site-packages is not writeable\n",
#      39       "Looking in links: https://storage.googleapis.com/jax-releases/jax_cuda_releases.html\n",
#      40       "Collecting jax[cuda12_pip]\n",
#      41       "  Using cached jax-0.4.30-py3-none-any.whl.metadata (22 kB)\n",
#      42       "Collecting jaxlib<=0.4.30,>=0.4.27 (from jax[cuda12_pip])\n",
#      43       "  Using cached jaxlib-0.4.30-cp39-cp39-manylinux2014_x86_64.whl.metadata (1.0 kB)\n",
#      44       "Requirement already satisfied: ml-dtypes>=0.2.0 in /home/a/a270285/.local/lib/python3.9/site-packages (from jax[cuda12_pip]) (0.5.1)\n",
#      45       "Requirement already satisfied: numpy>=1.22 in /home/a/a270285/.local/lib/python3.9/site-packages (from jax[cuda12_pip]) (2.0.2)\n",
#      46       "Requirement already satisfied: opt-einsum in /home/a/a270285/.local/lib/python3.9/site-packages (from jax[cuda12_pip]) (3.4.0)\n",
#      47       "Requirement already satisfied: scipy>=1.9 in /home/a/a270285/.local/lib/python3.9/site-packages (from jax[cuda12_pip]) (1.13.1)\n",
#      48       "Requirement already satisfied: importlib-metadata>=4.6 in /sw/spack-levante/jupyterhub/jupyterhub/lib/python3.9/site-packages (from jax[cuda12_pip]) (5.0.0)\n",
#      49       "Requirement already satisfied: jax-cuda12-plugin<=0.4.30,>=0.4.30 in /home/a/a270285/.local/lib/python3.9/site-packages (from jax-cuda12-plugin[with_cuda]<=0.4.30,>=0.4.30; extra == \"cuda12-pip\"->jax[cuda12_pip]) (0.4.30)\n",
#      50       "Requirement already satisfied: jax-cuda12-pjrt==0.4.30 in /home/a/a270285/.local/lib/python3.9/site-packages (from jax-cuda12-plugin<=0.4.30,>=0.4.30->jax-cuda12-plugin[with_cuda]<=0.4.30,>=0.4.30; extra == \"cuda12-pip\"->jax[cuda12_pip]) (0.4.30)\n",
#      51       "Requirement already satisfied: nvidia-cublas-cu12>=12.1.3.1 in /home/a/a270285/.local/lib/python3.9/site-packages (from jax-cuda12-plugin[with_cuda]<=0.4.30,>=0.4.30; extra == \"cuda12-pip\"->jax[cuda12_pip]) (12.9.1.4)\n",
#      52       "Requirement already satisfied: nvidia-cuda-cupti-cu12>=12.1.105 in /home/a/a270285/.local/lib/python3.9/site-packages (from jax-cuda12-plugin[with_cuda]<=0.4.30,>=0.4.30; extra == \"cuda12-pip\"->jax[cuda12_pip]) (12.9.79)\n",
#      53       "Requirement already satisfied: nvidia-cuda-nvcc-cu12>=12.1.105 in /home/a/a270285/.local/lib/python3.9/site-packages (from jax-cuda12-plugin[with_cuda]<=0.4.30,>=0.4.30; extra == \"cuda12-pip\"->jax[cuda12_pip]) (12.9.86)\n",
#      54       "Requirement already satisfied: nvidia-cuda-runtime-cu12>=12.1.105 in /home/a/a270285/.local/lib/python3.9/site-packages (from jax-cuda12-plugin[with_cuda]<=0.4.30,>=0.4.30; extra == \"cuda12-pip\"->jax[cuda12_pip]) (12.9.79)\n",
#      55       "Requirement already satisfied: nvidia-cudnn-cu12<10.0,>=9.0 in /home/a/a270285/.local/lib/python3.9/site-packages (from jax-cuda12-plugin[with_cuda]<=0.4.30,>=0.4.30; extra == \"cuda12-pip\"->jax[cuda12_pip]) (9.10.2.21)\n",
#      56       "Requirement already satisfied: nvidia-cufft-cu12>=11.0.2.54 in /home/a/a270285/.local/lib/python3.9/site-packages (from jax-cuda12-plugin[with_cuda]<=0.4.30,>=0.4.30; extra == \"cuda12-pip\"->jax[cuda12_pip]) (11.4.1.4)\n",
#      57       "Requirement already satisfied: nvidia-cusolver-cu12>=11.4.5.107 in /home/a/a270285/.local/lib/python3.9/site-packages (from jax-cuda12-plugin[with_cuda]<=0.4.30,>=0.4.30; extra == \"cuda12-pip\"->jax[cuda12_pip]) (11.7.5.82)\n",
#      58       "Requirement already satisfied: nvidia-cusparse-cu12>=12.1.0.106 in /home/a/a270285/.local/lib/python3.9/site-packages (from jax-cuda12-plugin[with_cuda]<=0.4.30,>=0.4.30; extra == \"cuda12-pip\"->jax[cuda12_pip]) (12.5.10.65)\n",
#      59       "Requirement already satisfied: nvidia-nccl-cu12>=2.18.1 in /home/a/a270285/.local/lib/python3.9/site-packages (from jax-cuda12-plugin[with_cuda]<=0.4.30,>=0.4.30; extra == \"cuda12-pip\"->jax[cuda12_pip]) (2.27.5)\n",
#      60       "Requirement already satisfied: nvidia-nvjitlink-cu12>=12.1.105 in /home/a/a270285/.local/lib/python3.9/site-packages (from jax-cuda12-plugin[with_cuda]<=0.4.30,>=0.4.30; extra == \"cuda12-pip\"->jax[cuda12_pip]) (12.9.86)\n",
#      61       "Requirement already satisfied: zipp>=0.5 in /sw/spack-levante/jupyterhub/jupyterhub/lib/python3.9/site-packages (from importlib-metadata>=4.6->jax[cuda12_pip]) (3.10.0)\n",
#      62       "Using cached jax-0.4.30-py3-none-any.whl (2.0 MB)\n",
#      63       "Using cached jaxlib-0.4.30-cp39-cp39-manylinux2014_x86_64.whl (79.6 MB)\n",
#      64       "Installing collected packages: jaxlib, jax\n",
#      65       "\u001b[2K   \u001b━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\u001b \u001b2/2\u001b [jax]\u001b1/2\u001b [jax]\n",
#      66       "\u001b[1A\u001b[2KSuccessfully installed jax-0.4.30 jaxlib-0.4.30\n"
#      67      ]
#      68     }
#      69    ],
#      70    "source": [
#      71     "!pip install --upgrade pip\n",
#      72     "!pip install --upgrade \"jax[cuda12_pip]\" -f https://storage.googleapis.com/jax-releases/jax_cuda_releases.html\n"
#      73    ]
#      74   },
#      75   {
#      76    "cell_type": "code",
#      77    "execution_count": 8,
#      78    "id": "3649371e-4c65-4ad1-9417-668b12185cb2",
#      79    "metadata": {},
#      80    "outputs": [],
#      81    "source": [
#      82     "import jax\n",
#      83     "import jax.numpy as jnp\n",
#      84     "from jax.lax import fori_loop, cond, scan\n",
#      85     "from jax import vmap, jit\n",
#      86     "from scipy.sparse import csc_matrix, identity\n",
#      87     "from scipy.sparse.linalg import cg, gmres\n",
#      88     "import math\n",
#      89     "import numpy as np\n",
#      90     "import matplotlib.pyplot as plt\n",
#      91     "from functools import partial\n",
#      92     "\n",
#      93     "def make_tri(nodnum: jnp.ndarray, nx: int, ny: int):\n",
#      94     "    def make_tri(n, nn):\n",
#      95     "        return jnp.array([nodnum[nn, n], nodnum[nn+1, n], nodnum[nn, n+1]]), jnp.array([nodnum[nn+1, n], nodnum[nn+1, n+1], nodnum[nn, n+1]])\n",
#      96     "\n",
#      97     "    b = jnp.reshape(vmap(lambda i: jnp.tile(i, nx-1))(jnp.arange(ny-1)), [(nx-1)*(ny-1)])\n",
#      98     "    a = jnp.tile(jnp.arange(nx-1), nx-1)\n",
#      99     "\n",
#     100     "    tri = vmap(make_tri)(b, a)\n",
#     101     "    return jnp.reshape(jnp.concatenate((tri[0], tri[1]), axis=1), [2*(nx-1)*(ny-1), 3])\n",
#     102     "\n",
#     103     "\n",
#     104     "def neighboring_triangles(n2d: int, e2d: int, tri: np.ndarray):\n",
#     105     "    # Initialize an array to store the count of neighboring triangles for each node.\n",
#     106     "    ne_num = np.zeros([n2d], dtype=int)\n",
#     107     "\n",
#     108     "    # Loop through each triangle (element) in the mesh.\n",
#     109     "    for n in range(e2d):\n",
#     110     "        enodes = tri[n, :]\n",
#     111     "        # Increment the count of neighboring triangles for each node in the current triangle.\n",
#     112     "        ne_num[enodes] += 1\n",
#     113     "\n",
#     114     "    # Initialize an array to store the positions of neighboring triangles for each node.\n",
#     115     "    ne_pos = np.zeros([int(np.max(ne_num)), n2d], dtype=int)\n",
#     116     "\n",
#     117     "    # Reset the array to store the count of neighboring triangles for each node.\n",
#     118     "    ne_num = np.zeros([n2d], dtype=int)\n",
#     119     "\n",
#     120     "    # Loop through each triangle (element) in the mesh.\n",
#     121     "    for n in range(e2d):\n",
#     122     "        enodes = tri[n, :]\n",
#     123     "        # Loop through the nodes of the current triangle.\n",
#     124     "        for j in range(3):\n",
#     125     "            # Store the position of the current neighboring triangle for the corresponding node.\n",
#     126     "            ne_pos[ne_num[enodes[j]], enodes[j]] = n\n",
#     127     "            # Increment the count of neighboring triangles for the node.\n",
#     128     "        ne_num[enodes] += 1\n",
#     129     "\n",
#     130     "    return ne_num, ne_pos\n",
#     131     "\n",
#     132     "\n",
#     133     "def neighbouring_nodes(n2d: int, tri: np.ndarray, ne_num: np.ndarray, ne_pos: np.ndarray):\n",
#     134     "    nn_num = np.zeros([n2d], dtype=int)\n",
#     135     "    check = np.zeros([n2d], dtype=int)\n",
#     136     "    aux = np.zeros([10], dtype=int)\n",
#     137     "    for j in range(n2d):\n",
#     138     "        cc = 0\n",
#     139     "        for m in range(ne_num[j]):\n",
#     140     "            el = ne_pos[m, j]\n",
#     141     "            for k in range(3):\n",
#     142     "                a = tri[el, k]\n",
#     143     "                if check[a] == 0:\n",
#     144     "                    check[a] = 1\n",
#     145     "                    aux[cc] = a\n",
#     146     "                    cc += 1\n",
#     147     "\n",
#     148     "        nn_num[j] = cc\n",
#     149     "        check[aux[0:cc]] = 0\n",
#     150     "\n",
#     151     "    nn_pos = np.zeros([np.max(nn_num), n2d], dtype=int)\n",
#     152     "\n",
#     153     "    for j in range(n2d):\n",
#     154     "        cc = 0\n",
#     155     "        for m in range(ne_num[j]):\n",
#     156     "            el = ne_pos[m, j]\n",
#     157     "            for k in range(3):\n",
#     158     "                a = tri[el, k]\n",
#     159     "                if check[a] == 0:\n",
#     160     "                    check[a] = 1\n",
#     161     "                    aux[cc] = a\n",
#     162     "                    cc += 1\n",
#     163     "\n",
#     164     "        nn_pos[0:cc, j] = aux[0:cc].T\n",
#     165     "        check[aux[0:cc]] = 0\n",
#     166     "\n",
#     167     "    return nn_num, nn_pos\n",
#     168     "\n",
#     169     "\n",
#     170     "def areas(n2d: int, e2d: int, tri: np.ndarray, xcoord: np.ndarray, ycoord: np.ndarray, ne_num: np.ndarray,\n",
#     171     "          ne_pos: np.ndarray, meshtype: str, carthesian: bool, cyclic_length):\n",
#     172     "    dx = np.zeros([e2d, 3], dtype=float)\n",
#     173     "    dy = np.zeros([e2d, 3], dtype=float)\n",
#     174     "    elem_area = np.zeros([e2d])\n",
#     175     "    r_earth = 6400  # Earth's radius, assuming units in kilometers\n",
#     176     "    Mt = np.ones([e2d])\n",
#     177     "\n",
#     178     "    if meshtype == 'm':\n",
#     179     "        for n in range(e2d):\n",
#     180     "            # Calculate differences in x and y coordinates for triangle vertices.\n",
#     181     "            x2 = xcoord[tri[n, 1]] - xcoord[tri[n, 0]]\n",
#     182     "            x3 = xcoord[tri[n, 2]] - xcoord[tri[n, 0]]\n",
#     183     "            y2 = ycoord[tri[n, 1]] - ycoord[tri[n, 0]]\n",
#     184     "            y3 = ycoord[tri[n, 2]] - ycoord[tri[n, 0]]\n",
#     185     "\n",
#     186     "            # Calculate determinant of the Jacobian matrix for this triangle.\n",
#     187     "            d = x2 * y3 - y2 * x3\n",
#     188     "\n",
#     189     "            # Calculate x and y derivatives of P1 basis functions.\n",
#     190     "            dx[n, 0] = (-y3 + y2) / d\n",
#     191     "            dx[n, 1] = y3 / d\n",
#     192     "            dx[n, 2] = -y2 / d\n",
#     193     "\n",
#     194     "            dy[n, 0] = -(-x3 + x2) / d\n",
#     195     "            dy[n, 1] = -x3 / d\n",
#     196     "            dy[n, 2] = x2 / d\n",
#     197     "\n",
#     198     "            # Calculate the area of the triangle.\n",
#     199     "            elem_area[n] = 0.5 * abs(d)\n",
#     200     "\n",
#     201     "    elif meshtype == 'r':\n",
#     202     "        rad = math.pi / 180.0\n",
#     203     "        if carthesian:\n",
#     204     "            Mt = np.ones([e2d])\n",
#     205     "        else:\n",
#     206     "            Mt = np.cos(np.sum(rad * ycoord[tri], axis=1) / 3.0)\n",
#     207     "\n",
#     208     "        for n in range(e2d):\n",
#     209     "            # Calculate differences in longitude and latitude for triangle vertices.\n",
#     210     "            x2 = rad * (xcoord[tri[n, 1]] - xcoord[tri[n, 0]])\n",
#     211     "            x3 = rad * (xcoord[tri[n, 2]] - xcoord[tri[n, 0]])\n",
#     212     "            y2 = r_earth * rad * (ycoord[tri[n, 1]] - ycoord[tri[n, 0]])\n",
#     213     "            y3 = r_earth * rad * (ycoord[tri[n, 2]] - ycoord[tri[n, 0]])\n",
#     214     "\n",
#     215     "            # Adjust for cyclic boundaries.\n",
#     216     "            if x2 > cyclic_length / 2.0:\n",
#     217     "                x2 = x2 - cyclic_length\n",
#     218     "            if x2 < -cyclic_length / 2.0:\n",
#     219     "                x2 = x2 + cyclic_length\n",
#     220     "            if x3 > cyclic_length / 2.0:\n",
#     221     "                x3 = x3 - cyclic_length\n",
#     222     "            if x3 < -cyclic_length / 2.0:\n",
#     223     "                x3 = x3 + cyclic_length\n",
#     224     "\n",
#     225     "            # Apply metric factors and calculate x and y derivatives of P1 basis functions.\n",
#     226     "            x2 = r_earth * x2 * Mt[n]\n",
#     227     "            x3 = r_earth * x3 * Mt[n]\n",
#     228     "            d = x2 * y3 - y2 * x3\n",
#     229     "\n",
#     230     "            dx[n, 0] = (-y3 + y2) / d\n",
#     231     "            dx[n, 1] = y3 / d\n",
#     232     "            dx[n, 2] = -y2 / d\n",
#     233     "\n",
#     234     "            dy[n, 0] = -(-x3 + x2) / d\n",
#     235     "            dy[n, 1] = -x3 / d\n",
#     236     "            dy[n, 2] = x2 / d\n",
#     237     "\n",
#     238     "            # Calculate the area of the triangle.\n",
#     239     "            elem_area[n] = 0.5 * abs(d)\n",
#     240     "\n",
#     241     "        if carthesian:\n",
#     242     "            Mt = np.zeros([e2d])\n",
#     243     "        else:\n",
#     244     "            Mt = (np.sin(rad * np.sum(ycoord[tri], axis=1) / 3.0) / Mt) / r_earth\n",
#     245     "\n",
#     246     "    # Calculate scalar cell (cluster) area for each node.\n",
#     247     "    area = np.zeros([n2d])\n",
#     248     "    for n in range(n2d):\n",
#     249     "        area[n] = np.sum(elem_area[ne_pos[0:ne_num[n], n]]) / 3.0\n",
#     250     "\n",
#     251     "    return area, elem_area, dx, dy, Mt\n",
#     252     "\n",
#     253     "\n",
#     254     "def make_smooth(Mt: jnp.ndarray, elem_area: jnp.ndarray, dx: jnp.ndarray, dy: jnp.ndarray, nn_num: jnp.ndarray,\n",
#     255     "                nn_pos: jnp.ndarray, tri: jnp.ndarray, n2d: int, e2d: int, full: bool = False):\n",
#     256     "\n",
#     257     "    smooth_m = jnp.zeros(nn_pos.shape, dtype=jnp.float32)\n",
#     258     "    metric = jnp.zeros(nn_pos.shape, dtype=jnp.float32)\n",
#     259     "    aux = jnp.zeros((n2d,), dtype=jnp.int32)\n",
#     260     "\n",
#     261     "    @jit\n",
#     262     "    def loop_body(j, carry):\n",
#     263     "        smooth_m, metric, aux, nn_num, nn_pos, elem_area, dx, dy, Mt = carry\n",
#     264     "        enodes = tri[j, :]\n",
#     265     "\n",
#     266     "        def inner_loop_body(n, carry):\n",
#     267     "            smooth_m, metric, aux, enodes, nn_num, nn_pos, elem_area, dx, dy, Mt = carry\n",
#     268     "            row = enodes[n]\n",
#     269     "            cc = nn_num[row]\n",
#     270     "\n",
#     271     "            def fill_xd(i, val):\n",
#     272     "                row, aux, nn_pos = val\n",
#     273     "                n = nn_pos[i, row]\n",
#     274     "                aux = aux.at[n].set(i)\n",
#     275     "                return row, aux, nn_pos\n",
#     276     "\n",
#     277     "            row, aux, _ = fori_loop(0, cc, fill_xd, (row, aux, nn_pos))\n",
#     278     "\n",
#     279     "            def update_smooth_m(m, carry):\n",
#     280     "                smooth_m, metric, aux, enodes, elem_area, dx, dy, n = carry\n",
#     281     "                col = enodes[m]\n",
#     282     "                pos = aux[col]\n",
#     283     "                tmp_x = dx[m] * dx[n]\n",
#     284     "                tmp_y = dy[n] * dy[m]\n",
#     285     "                c1 = m == n\n",
#     286     "\n",
#     287     "                smooth_m = smooth_m.at[pos, row].add(cond(c1 & full,\n",
#     288     "                                                          lambda: (tmp_x + tmp_y) * elem_area + jnp.square(\n",
#     289     "                                                              Mt) * elem_area / 3.0,\n",
#     290     "                                                          lambda: (tmp_x + tmp_y) * elem_area\n",
#     291     "                                                          )\n",
#     292     "                                                     )\n",
#     293     "                metric = metric.at[pos, row].add(Mt * (dx[n] - dx[m]) * elem_area / 3.0)\n",
#     294     "                return smooth_m, metric, aux, enodes, elem_area, dx, dy, n\n",
#     295     "\n",
#     296     "            smooth_m, metric, aux, _, _, _, _, _ = fori_loop(0, 3, update_smooth_m,\n",
#     297     "                                                             (smooth_m, metric, aux, enodes, elem_area, dx, dy, n))\n",
#     298     "            return smooth_m, metric, aux, enodes, nn_num, nn_pos, elem_area, dx, dy, Mt\n",
#     299     "\n",
#     300     "        smooth_m, metric, aux, _, _, _, _, _, _, _ = fori_loop(0, 3, inner_loop_body, (\n",
#     301     "        smooth_m, metric, aux, enodes, nn_num, nn_pos, elem_area[j], dx[j, :], dy[j, :], Mt[j]))\n",
#     302     "        return smooth_m, metric, aux, nn_num, nn_pos, elem_area, dx, dy, Mt\n",
#     303     "\n",
#     304     "    smooth_m, metric, _, _, _, _, _, _, _ = fori_loop(0, e2d, loop_body,\n",
#     305     "                                                      (smooth_m, metric, aux, nn_num, nn_pos, elem_area, dx, dy, Mt))\n",
#     306     "    return smooth_m, metric\n",
#     307     "\n",
#     308     "\n",
#     309     "@partial(jit, static_argnums=[3, 4])\n",
#     310     "def make_smat(nn_pos: jnp.ndarray, nn_num: jnp.ndarray, smooth_m: jnp.ndarray, n2d: int, nza: int):\n",
#     311     "    def helper(carry, x):\n",
#     312     "        n, m = carry\n",
#     313     "        out = (smooth_m[m, n], n, nn_pos[m, n])\n",
#     314     "        n, m = cond(m + 1 >= nn_num[n], lambda: cond(n + 1 >= n2d, lambda: (0, 0), lambda: (n + 1, 0)),\n",
#     315     "                    lambda: (n, m + 1))\n",
#     316     "        return (n, m), out\n",
#     317     "\n",
#     318     "    _, tmp = scan(helper, init=(0, 0), xs=jnp.arange(nza))\n",
#     319     "    ss, ii, jj = tmp\n",
#     320     "\n",
#     321     "    return ss, ii, jj\n",
#     322     "\n",
#     323     "\n",
#     324     "def create_synthetic_data(Lx, dxm):\n",
#     325     "    \n",
#     326     "    r_earth = 6400.0  # in km; wavenumbers will be in 1/km\n",
#     327     "    Ly = Lx\n",
#     328     "    dym = dxm\n",
#     329     "    cyclic = 0  # 1 if mesh is cyclic\n",
#     330     "    cyclic_length = 360  # in degrees; if not cyclic, take it larger than  zonal size\n",
#     331     "    cyclic_length = cyclic_length * math.pi / 180  # DO NOT TOUCH\n",
#     332     "    meshtype = 'm'  # coordinates can be in physical measure 'm' or in radians 'r'\n",
#     333     "    \n",
#     334     "    xx = np.arange(0, Lx + 1, dxm, dtype=\"float32\")\n",
#     335     "    yy = np.arange(0, Ly + 1, dym, dtype=\"float32\")\n",
#     336     "    \n",
#     337     "    # Create uniformity in the mesh\n",
#     338     "    # xx = np.concatenate((np.arange(0, 4*Lx//20 + 1, dxm), np.arange(5*Lx//20, Lx + 1, dxm)))\n",
#     339     "    # yy = np.concatenate((np.arange(0, 4*Ly//20 + 1, dym), np.arange(5*Ly//20, Ly + 1, dym)))\n",
#     340     "    \n",
#     341     "    nx = len(xx)\n",
#     342     "    ny = len(yy)\n",
#     343     "    \n",
#     344     "    nodnum = np.arange(0, nx * ny)\n",
#     345     "    xcoord = np.tile(xx, reps=(ny, 1)).T\n",
#     346     "    ycoord = np.tile(yy, reps=(nx, 1))\n",
#     347     "    @jit\n",
# --> 348     "    def make_ll(x, y):\n",
#     349     "        return jnp.sqrt(y * y + x * x)\n",
#     350     "    \n",
#     351     "    @jit\n",
#     352     "    def make_tff(ttf, ll):\n",
#     353     "        return ttf / (jnp.power(ll, 1.5))  # 1.5 for -2 spectrum\n",
#     354     "    \n",
#     355     "    tt = 50 * (np.random.random(xcoord.shape) - 0.5)\n",
#     356     "    ttf = np.fft.fft2(tt)\n",
#     357     "    # ============\n",
#     358     "    # Make spectrum red\n",
#     359     "    # ============\n",
#     360     "    espectrum = np.zeros((nx // 2 + 1))  # Place for Fourier spectrum\n",
#     361     "    kk = np.concatenate((np.arange(0, nx // 2 + 1), np.arange(-nx // 2 + 1, 0, 1)))  # Wavenumbers\n",
#     362     "    \n",
#     363     "    ll = vmap(vmap(make_ll, in_axes=(None, 0)), in_axes=(0, None))(kk, kk)\n",
#     364     "    ttf = vmap(vmap(make_tff, in_axes=(0, 0)), in_axes=(0, 0))(ttf, ll)\n",
#     365     "    ttf = ttf.at[0, 0].set(0.0)\n",
#     366     "    \n",
#     367     "    tt = jnp.real(jnp.fft.ifft2(ttf))\n",
#     368     "    return jnp.reshape(tt, [nx*ny])\n",
#     369     "\n",
#     370     "\n",
#     371     "def create_synthetic_matrix(Lx, dxm, cartesian):\n",
#     372     "    def make_tri(nodnum: jnp.ndarray, nx: int, ny: int):\n",
#     373     "        def make_tri(n, nn):\n",
#     374     "            return jnp.array([nodnum[nn, n], nodnum[nn+1, n], nodnum[nn, n+1]]), jnp.array([nodnum[nn+1, n], nodnum[nn+1, n+1], nodnum[nn, n+1]])\n",
#     375     "    \n",
#     376     "        b = jnp.reshape(vmap(lambda i: jnp.tile(i, nx-1))(jnp.arange(ny-1)), [(nx-1)*(ny-1)])\n",
#     377     "        a = jnp.tile(jnp.arange(nx-1), nx-1)\n",
#     378     "    \n",
#     379     "        tri = vmap(make_tri)(b, a)\n",
#     380     "        return jnp.reshape(jnp.concatenate((tri[0], tri[1]), axis=1), [2*(nx-1)*(ny-1), 3])\n",
#     381     "    \n",
#     382     "    r_earth = 6400.0  # in km; wavenumbers will be in 1/km\n",
#     383     "    Ly = Lx\n",
#     384     "    dym = dxm\n",
#     385     "    cyclic = 0  # 1 if mesh is cyclic\n",
#     386     "    cyclic_length = 360  # in degrees; if not cyclic, take it larger than  zonal size\n",
#     387     "    cyclic_length = cyclic_length * math.pi / 180  # DO NOT TOUCH\n",
#     388     "    meshtype = 'm'  # coordinates can be in physical measure 'm' or in radians 'r'\n",
#     389     "    \n",
#     390     "    xx = np.arange(0, Lx + 1, dxm, dtype=\"float32\")\n",
#     391     "    yy = np.arange(0, Ly + 1, dym, dtype=\"float32\")\n",
#     392     "    \n",
#     393     "    # Create uniformity in the mesh\n",
#     394     "    # xx = np.concatenate((np.arange(0, 4*Lx//20 + 1, dxm), np.arange(5*Lx//20, Lx + 1, dxm)))\n",
#     395     "    # yy = np.concatenate((np.arange(0, 4*Ly//20 + 1, dym), np.arange(5*Ly//20, Ly + 1, dym)))\n",
#     396     "    \n",
#     397     "    nx = len(xx)\n",
#     398     "    ny = len(yy)\n",
#     399     "    \n",
#     400     "    nodnum = np.arange(0, nx * ny)\n",
#     401     "    xcoord = np.tile(xx, reps=(ny, 1)).T\n",
#     402     "    ycoord = np.tile(yy, reps=(nx, 1))\n",
#     403     "\n",
#     404     "    # == == == == == == == =\n",
#     405     "    # Reshape to 1D arrays\n",
#     406     "    # == == == == == == == =\n",
#     407     "    nodnum = np.reshape(nodnum, [ny, nx]).T\n",
#     408     "    xcoord = np.reshape(xcoord, [nx * ny])\n",
#     409     "    ycoord = np.reshape(ycoord, [nx * ny])\n",
#     410     "    \n",
#     411     "    xcoord /= r_earth\n",
#     412     "    ycoord /= r_earth\n",
#     413     "    alpha = math.pi/3 + math.pi/12\n",
#     414     "    zg = np.sin(ycoord)\n",
#     415     "    xg = np.cos(ycoord) * np.cos(xcoord)\n",
#     416     "    yg = np.cos(ycoord) * np.sin(xcoord)\n",
#     417     "    # Rotate by alpha\n",
#     418     "    zn = zg * np.cos(alpha) + xg * np.sin(alpha)\n",
#     419     "    xg = -zg * np.sin(alpha) + xg * np.cos(alpha)\n",
#     420     "    # New coordinates in radians\n",
#     421     "    ycoord = np.arcsin(zn)\n",
#     422     "    xcoord = np.arctan2(yg,xg)\n",
#     423     "    # New coordinates in degrees\n",
#     424     "    ycoord = (180/math.pi) * np.arcsin(zn)\n",
#     425     "    xcoord = (180/math.pi) * np.arctan2(yg,xg)\n",
#     426     "    \n",
#     427     "    make_tri = jit(make_tri, static_argnums=[1, 2])\n",
#     428     "    \n",
#     429     "    tri = make_tri(nodnum, nx, ny)\n",
#     430     "    tri = np.array(tri)\n",
#     431     "    n2d = len(xcoord)  # The number of vertices(nodes)\n",
#     432     "    e2d = len(tri[:, 1])  # The number of triangles(elements)\n",
#     433     "    ne_num, ne_pos = neighboring_triangles(n2d, e2d, tri)\n",
#     434     "    nn_num, nn_pos = neighbouring_nodes(n2d, tri, ne_num, ne_pos)\n",
#     435     "    area, elem_area, dx, dy, Mt = areas(n2d, e2d, tri, xcoord, ycoord, ne_num, ne_pos, meshtype, cartesian, cyclic_length)\n",
#     436     "    \n",
#     437     "    # Move data to JAX\n",
#     438     "    jelem_area = jnp.array(elem_area)\n",
#     439     "    jdx = jnp.array(dx)\n",
#     440     "    jdy = jnp.array(dy)\n",
#     441     "    jnn_num = jnp.array(nn_num)\n",
#     442     "    jnn_pos = jnp.array(nn_pos)\n",
#     443     "    jtri = jnp.array(tri)\n",
#     444     "    jarea = jnp.array(area)\n",
#     445     "    jMt = jnp.array(Mt)\n",
#     446     "    \n",
#     447     "    with jax.default_device(jax.devices(\"cpu\")[0]): # Force JAX to use CPU\n",
#     448     "        jsmooth, metric = make_smooth(jMt, jelem_area, jdx, jdy, jnn_num, jnn_pos, jtri, n2d, e2d, False)\n",
#     449     "        ss, ii, jj = make_smat(jnn_pos, jnn_num, jsmooth, n2d, int(jnp.sum(jnn_num)))\n",
#     450     "    return ss, ii, jj, tri, xcoord, ycoord"
#     451    ]
#     452   },
#     453   {
#     454    "cell_type": "code",
#     455    "execution_count": null,
#     456    "id": "75b3f58d-6ca9-4e2a-b0ec-edd460e17560",
#     457    "metadata": {},
#     458    "outputs": [],
#     459    "source": []
#     460   }
#     461  ],
#     462  "metadata": {
#     463   "kernelspec": {
#     464    "display_name": "Python (NaomiKernel)",
#     465    "language": "python",
#     466    "name": "naomikernel"
#     467   },
#     468   "language_info": {
#     469    "codemirror_mode": {
#     470     "name": "ipython",
#     471     "version": 3
#     472    },
#     473    "file_extension": ".py",
#     474    "mimetype": "text/x-python",
#     475    "name": "python",
#     476    "nbconvert_exporter": "python",
#     477    "pygments_lexer": "ipython3",
#     478    "version": "3.10.16"
#     479   }
#     480  },
#     481  "nbformat": 4,
#     482  "nbformat_minor": 5
#     483 }
#
#     [... skipping hidden 11 frame]
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/compiler.py:385, in backend_compile_and_load(backend, module, executable_devices, options, host_callbacks)
#     376       return backend.compile_and_load(
#     377           built_c,
#     378           executable_devices=executable_devices,
#     379           compile_options=options,
#     380           host_callbacks=host_callbacks,
#     381       )
#     382     # Some backends don't have `host_callbacks` option yet
#     383     # TODO(sharadmv): remove this fallback when all backends allow `compile`
#     384     # to take in `host_callbacks`
# --> 385     return backend.compile_and_load(
#     386         built_c,
#     387         executable_devices=executable_devices,
#     388         compile_options=options,
#     389     )
#     390 except xc.XlaRuntimeError as e:
#     391   for error_handler in _XLA_RUNTIME_ERROR_HANDLERS:
#
# XlaRuntimeError: FAILED_PRECONDITION: DNN library initialization failed. Look at the errors above for more details.

# %%
plt.rcParams['figure.figsize'] = [12, 6]
triang = mpl.tri.Triangulation(xcoord, ycoord, tri)

plt.tripcolor(triang, tt)
plt.colorbar()

# %%
num_layers = 8              # number of layers in GNP
embed = 32                  # embedding dimension in GNP
hidden = 64                 # hidden dimension in MLPs in GNP
drop_rate = 0.05            # dropout rate in GNP
disable_scale_input = False # whether disable the scaling of inputs in GNP
dtype = torch.float64       # training precision for GNP
lr = 2e-3                   # learning rate in training GNP
weight_decay = 0.0          # weight decay in training GNP
training_data = 'x_mix'     # type of training data x
m = 80                      # Krylov subspace dimension for training data
batch_size = 4              # batch size in training GNP
grad_accu_steps = 1         # gradient accumulation steps in training GNP
epochs = 1000               # number of epochs in training GNP

# %%
kc = 2 * math.pi / np.logspace(1, 3, 10) # 10 values from 10 to 1000 km

# %%
tt.shape

# %%
n = 1 # Filter order
device = torch.device("cuda")
solver = GMRES()
As = []

for k in kc: # Looping over the scales
    Smat1 = csc_matrix((ss * (1.0 / np.square(k)), (ii, jj)), shape=(n2d, n2d))
    Smat = identity(n2d) + 2.0 * (Smat1 ** n)
    A = torch.sparse_csc_tensor(Smat.indptr, Smat.indices, Smat.data, Smat.shape, dtype=torch.float64).to(device)
    A = scale_A_by_spectral_radius(A)
    As += [A]
    
data = torch.tensor(np.array(tt), device=device, dtype=torch.float64)

# %%
net = ResGCN(As[-1], num_layers, embed, hidden, drop_rate, scale_input=True, dtype=dtype).to(device)
optimizer = torch.optim.Adam(net.parameters(), lr=lr, weight_decay=weight_decay)
scheduler = None
M = GNP(A, training_data, m, net, device)

# %%
iterations = np.zeros(len(As))

for i in range(len(As)):
    ttw = data - As[i] @ data  # Work with perturbations
    x, iters, _, _, _ = solver.solve(A=As[i], b=ttw, rtol=1e-6, max_iters=20000, progress_bar=False)
    print("Iteration " + str(iters))
    iterations[i] = iters

# %%
plt.plot(np.logspace(1, 3, 10), iterations)
plt.xlabel("Length [km]")
plt.ylabel("Iterations")
plt.xscale("log")
plt.yscale("log")

# %%
import time 

tic = time.time()
hist_loss, best_loss, best_epoch, model_file = M.train(
    batch_size, grad_accu_steps, epochs, optimizer, scheduler, num_workers=4,
    checkpoint_prefix_with_path="./tmp_", progress_bar=False)
M.net.load_state_dict(torch.load(f"./tmp_epoch_{best_epoch}.pt", map_location=device, weights_only=True))

print(f'Done. Training time: {time.time()-tic} seconds')
print(f'Loss: inital = {hist_loss[0]}, final = {hist_loss[-1]}, best = {best_loss}, epoch = {best_epoch}')

# %%
iterations_pre = np.zeros(len(As))

for i in range(len(As)):
    ttw = data - As[i] @ data  # Work with perturbations
    x, iters, _, _, _ = solver.solve(A=As[i], b=ttw, rtol=1e-6, max_iters=20000, progress_bar=False, M=M)
    print("Iteration " + str(iters))
    iterations_pre[i] = iters

# %%
plt.plot(np.logspace(1, 3, 10), iterations, label="No preconditioner")
plt.plot(np.logspace(1, 3, 10), iterations_pre, label="One phase of training")

plt.xlabel("Length [km]")
plt.ylabel("Iterations")
plt.xscale("log")
plt.yscale("log")
plt.legend()

# %%
! rm ./*.pt

# %%
net = ResGCN(As[0], num_layers, embed, hidden, drop_rate, scale_input=True, dtype=dtype).to(device)
optimizer = torch.optim.Adam(net.parameters(), lr=lr, weight_decay=weight_decay)
scheduler = None
M = GNP(A, training_data, m, net, device)

for A in As: 
    M.A = A
    hist_loss, best_loss, best_epoch, model_file = M.train(
    batch_size, grad_accu_steps, epochs // 10, optimizer, scheduler, num_workers=4, 
    checkpoint_prefix_with_path="./tmp_", progress_bar=False)
    M.net.load_state_dict(torch.load(f"./tmp_epoch_{best_epoch}.pt", map_location=device, weights_only=True))
    print(f'Loss: inital = {hist_loss[0]}, final = {hist_loss[-1]}, best = {best_loss}, epoch = {best_epoch}')

# %%
iterations_post = np.zeros(len(As))

for i in range(len(As)):
    ttw = data - As[i] @ data  # Work with perturbations
    x, iters, _, _, _ = solver.solve(A=As[i], b=ttw, rtol=1e-6, max_iters=20000, progress_bar=False, M=M)
    print("Iteration " + str(iters))
    iterations_post[i] = iters

# %%
plt.plot(np.logspace(1, 3, 10), iterations, label="No preconditioner")
plt.plot(np.logspace(1, 3, 10), iterations_pre, label="One phase of training")
plt.plot(np.logspace(1, 3, 10), iterations_post, label="10 phases of training")

plt.xlabel("Length [km]")
plt.ylabel("Iterations")
plt.xscale("log")
plt.yscale("log")
plt.legend()
